# %%
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
import numpy as np
import copy
from datetime import datetime, timedelta
import sys
import os

# %load_ext autoreload
# %autoreload 1
# %aimport get_manobs_soundings_pr_df

grav = 9.81
# Out:
# /fs/site8/eccc/crd/cccma/users/rml000/UQAM/projet_margaux/Pour_Mathieu_fig4/create_figure_papier/wintre-mix_fzra_and_pl/soundings_functions.py:185: SyntaxWarning: invalid escape sequence '\s'
#   sep='\s+',
# /fs/site8/eccc/crd/cccma/users/rml000/UQAM/projet_margaux/Pour_Mathieu_fig4/create_figure_papier/wintre-mix_fzra_and_pl/kin1d_functions.py:508: SyntaxWarning: invalid escape sequence '\s'
#   temp_prof = pd.read_csv(path_wintremi_soundings+'IOP'+str(IOP_number).zfill(2)+'/master/'+list_s[sounding_number],skiprows=[1,2],header=0, encoding='ISO-8859-1',sep='\s+')

# %% [markdown]
# # Use functions inside get_manobs_soundings_pr_df.py

# %%
# Default use
#s wet bulb temperature
df_all_events_tw, df_all_events_temp,df_all_events_tw_sounding, df_all_events_temp_sounding = get_manobs_soundings_pr_df.get_all_event_df()
# Out:
# /fs/site8/eccc/crd/cccma/users/rml000/UQAM/projet_margaux/Pour_Mathieu_fig4/create_figure_papier/wintre-mix_fzra_and_pl/get_manobs_soundings_pr_df.py:329: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   man_obs = man_obs.applymap(lambda x: None if pd.isna(x) else x)
# upperair.sounding.202202022100.Albany_DOW-US_Plattsburgh.txt
# upperair.sounding.202202030100.Albany_DOW-US_Plattsburgh.txt
# upperair.sounding.202202030230.Albany_DOW-US_Plattsburgh.txt
# upperair.sounding.202202030400.Albany_DOW-US_Plattsburgh.txt
# upperair.sounding.202202030530.Albany_DOW-US_Plattsburgh.txt
# upperair.sounding.202202030700.Albany_DOW-US_Plattsburgh.txt
# upperair.sounding.202202100800.Albany_DOW-US_N.txt
# upperair.sounding.202202101030.Albany_DOW-US_N.txt
# upperair.sounding.202202101200.Albany_DOW-US_N.txt
# upperair.sounding.202202120100.Albany_DOW-US_N.txt
# upperair.sounding.202202120230.Albany_DOW-US_N.txt
# ...

# %%
df_all_events_tw   = get_manobs_soundings_pr_df.add_pr_t_rh(df_all_events_tw)
df_all_events_temp = get_manobs_soundings_pr_df.add_pr_t_rh(df_all_events_temp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/ords/anaconda3/xesmf_env/lib/python3.13/site-packages/xarray/backends/file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File ~/ords/anaconda3/xesmf_env/lib/python3.13/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# ...

# %% [markdown]
# # Save output

# %%
df_all_events_tw.to_csv('df_all_events_tw_29juillet2026.csv')
df_all_events_temp.to_csv('df_all_events_temp_29juillet2026.csv')

# %%
df_all_events_temp.manobs_with_mix.value_counts()
# Out:
# manobs_with_mix
# RA             490
# SN             286
# FZRA           160
# PL             149
# SN and PL       65
# FZRA and PL     47
# SN and RA       25
# RA and PL       12
# SN and FZRA      8
# Name: count, dtype: int64
